# %% [markdown]
# # Movement recognition
#
# The human movement recognition is based on the assumption that specific body movements obtained from on-body or ambient sensors translate into specific signal patterns, which can be identified/classified using machine learning or deep learning techniques.
#
# In the notebook is used K-means Clustering for Time Series with Dynamic Time Warping.

# %% [markdown]
# # Loading the dataset

# %% [markdown]
# ### Import the needed libraries

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import matplotlib
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
from tslearn.metrics import soft_dtw
from tslearn.clustering import TimeSeriesKMeans
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, \
    TimeSeriesResampler
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.metrics import silhouette_score

# %%
df_train=pd.read_csv(r'data\\unlabeled\\set_65.csv')
df_train.shape
# Out:
# (132666, 29)

# %%
df_train_short = df_train.iloc[75:15000]

# %%
df_train_short =df_train_short.reset_index()

# %%
df_train_short.columns

# %%
# Create the training dataset
scale_columns = ['acc_x_n', 'acc_y_n', 'acc_z_n', 'alpha_r', 'beta_r','gyr_x_n', 'gyr_y_n', 'gyr_z_n']
df_train_short=df_train_short[scale_columns]

# %%
df_train_short.head(2)
# Out:
#     acc_x_n   acc_y_n   acc_z_n  alpha_r   beta_r   gyr_x_n   gyr_y_n  \
# 0  0.866943  0.091064 -0.529541 -15988.0 -14853.0 -0.823975  0.671387
# 1  0.870605  0.095703 -0.527588 -15988.0 -14853.0 -0.915527  0.671387
#
#     gyr_z_n
# 0  0.549316
# 1  0.579834

# %% [markdown]
# # Dimensionality reduction
# Converting the DataFrame into 2D features frame for further better cluster visualization

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(df_train_short)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#               PCA1         PCA2
# 0     -1878.955878  -346.016903
# 1     -1878.955873  -346.016662
# 2     -1878.955950  -346.016613
# 3     -1878.956006  -346.016026
# 4     -1878.956081  -346.016026
# ...            ...          ...
# 14920 -2678.745832  1033.727254
# 14921 -2632.727631   909.357914
# 14922 -2653.873365   876.192523
# 14923 -2666.963226   824.589158
# 14924 -2666.961877   824.583222
#
# [14925 rows x 2 columns]

# %% [markdown]
# # Normalization

# %% [markdown]
# TimeSeriesScalerMeanVariance: This scaler is such that each output time series has zero mean and unit variance. The assumption here is that the range of a given time series is uninformative and one only wants to compare shapes in an amplitude-invariant manner (when time series are multivariate, this also rescales all modalities such that there will not be a single modality responsible for a large part of the variance). This means that one cannot scale barycenters back to data range because each time series is scaled independently and there is hence no such thing as an overall data range.
#
# 3D array of shape (n_ts, sz, d) with the following conventions:
# - the fist axis is the sample axis, n_ts being the number of time series;
# - the second axis is the time axis, sz being the maximum number of time points;
# - the third axis is the dimension axis, d being the number of dimensions.

# %%
random_seed = 42
np.random.seed(random_seed)
X_train = TimeSeriesScalerMeanVariance().fit_transform(df_train_short) 
print(X_train.shape)
# Out:
# (14925, 8, 1)

# %% [markdown]
# # Model Building using KMeans

# %%
print("Soft-DTW k-means")

sdtw_km = TimeSeriesKMeans(n_clusters=5,
                           metric="softdtw",
                           n_init=2,
                           metric_params={"gamma": .01},
                           verbose=True,
                           max_iter=10,                    
                           random_state=random_seed)
sdtw_km.fit(X_train)
# Out:
# Soft-DTW k-means
# Init 1
# 0.004 --> 0.003 --> 0.003 --> 0.003 --> 0.003 --> 0.004 --> 0.004 --> 0.004 --> 0.004 --> 0.004 -->
# Init 2
# 0.008 --> 0.007 --> 0.007 --> 0.007 --> 0.007 --> 0.007 --> 0.007 --> 0.008 --> 0.008 --> 0.008 -->
# TimeSeriesKMeans(max_iter=10, metric='softdtw', metric_params={'gamma': 0.01},
#                  n_clusters=5, n_init=2, random_state=42, verbose=True)

# %% [markdown]
# # Plotting clusters

# %%
# Add cluster labels to the PCA DataFrame for vizualization
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':sdtw_km.labels_})],axis=1)
pca_df_kmeans.shape
# Out:
# (14925, 3)

# %%
plt.figure(figsize=(6,6))
palette= sns.color_palette()
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans, palette=palette)
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
np.unique(sdtw_km.labels_, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4], dtype=int64),
#  array([12199,   136,   336,  2243,    11], dtype=int64))

# %% [markdown]
# # Find all cluster centers

# %%
centroids_2D = sdtw_km.cluster_centers_
centroids_2D
# Out:
# array([[[ 0.57662394],
#         [ 0.57655992],
#         [ 0.57649362],
#         [-1.75933308],
#         [-1.70070755],
#         [ 0.57648222],
#         [ 0.57657922],
#         [ 0.57666452]],
#
#        [[ 0.45461075],
#         [ 0.45457665],
#         [-0.05732219],
#         [-2.57764617],
#         [ 0.37553652],
#         [ 0.45997311],
#         [ 0.46017044],
#         [ 0.45433012]],
#
#        [[ 0.55778331],
#         [ 0.55781302],
#         [ 0.55768247],
#         [-1.19593158],
#         [-2.1532145 ],
#         [ 0.55821142],
#         [ 0.55931012],
#         [ 0.55859012]],
#
#        [[ 0.55912104],
#         [ 0.55904349],
#         [ 0.55894058],
#         [-2.14562217],
#         [-1.20943569],
#         [ 0.55955389],
#         [ 0.5598286 ],
#         [ 0.55878494]],
#
#        [[ 0.09292879],
#         [ 0.09295443],
#         [ 0.09284312],
#         [-2.23834219],
#         [ 1.69689306],
#         [ 0.08831135],
#         [ 0.09219744],
#         [ 0.08754021]]])

# %%
fig, ax = plt.subplots(figsize=(3, 3))
plt.scatter(centroids_2D[:,0], centroids_2D[:,1], c='r', s=250, marker='s')
for i in range(len(centroids_2D)):
    plt.annotate(i, (centroids_2D[i][0], centroids_2D[i][1]), fontsize=11)

# %% [markdown]
# # Saving the kmeans clustering model and the data with cluster label

# %%
#Saving Scikitlearn models
import joblib
joblib.dump(sdtw_km, "soft_dtw_kmeans_model.pkl")
# Out:
# ['soft_dtw_kmeans_model.pkl']

# %%
from tslearn.utils import to_sklearn_dataset
cluster_df_sk = to_sklearn_dataset(X_train)
cluster_df_sk
df = pd.DataFrame(cluster_df_sk, columns =df_train_short.columns)
df.head()
# Out:
#     acc_x_n   acc_y_n   acc_z_n   alpha_r    beta_r   gyr_x_n   gyr_y_n  \
# 0  0.576939  0.576823  0.576730 -1.815401 -1.645577  0.576686  0.576910
# 1  0.576941  0.576825  0.576731 -1.815402 -1.645577  0.576673  0.576911
# 2  0.576949  0.576833  0.576740 -1.815402 -1.645576  0.576664  0.576901
# 3  0.576945  0.576828  0.576735 -1.815402 -1.645576  0.576650  0.576887
# 4  0.576953  0.576838  0.576744 -1.815402 -1.645576  0.576641  0.576878
#
#     gyr_z_n
# 0  0.576891
# 1  0.576897
# 2  0.576892
# 3  0.576933
# 4  0.576924

# %%
cluster_df = pd.concat([df, pd.DataFrame({'cluster':sdtw_km.labels_})],axis=1)
cluster_df.head()
# Out:
#     acc_x_n   acc_y_n   acc_z_n   alpha_r    beta_r   gyr_x_n   gyr_y_n  \
# 0  0.576939  0.576823  0.576730 -1.815401 -1.645577  0.576686  0.576910
# 1  0.576941  0.576825  0.576731 -1.815402 -1.645577  0.576673  0.576911
# 2  0.576949  0.576833  0.576740 -1.815402 -1.645576  0.576664  0.576901
# 3  0.576945  0.576828  0.576735 -1.815402 -1.645576  0.576650  0.576887
# 4  0.576953  0.576838  0.576744 -1.815402 -1.645576  0.576641  0.576878
#
#     gyr_z_n  cluster
# 0  0.576891        0
# 1  0.576897        0
# 2  0.576892        0
# 3  0.576933        0
# 4  0.576924        0

# %%
cluster_1_df = cluster_df[cluster_df["cluster"]==1]
cluster_1_df
# Out:
#         acc_x_n   acc_y_n   acc_z_n   alpha_r    beta_r   gyr_x_n   gyr_y_n  \
# 3082   0.397649  0.397642  0.397338 -2.641484  0.234524  0.371227  0.431909
# 3083   0.395793  0.395823  0.395509 -2.641904  0.243416  0.368693  0.434670
# 3084   0.438937  0.438989  0.438646 -2.610476 -0.050584  0.411297  0.482141
# 3085   0.438695  0.438692  0.438376 -2.610401 -0.050812  0.411450  0.485418
# 3086   0.438463  0.438436  0.438083 -2.610377 -0.051052  0.414139  0.486447
# ...         ...       ...       ...       ...       ...       ...       ...
# 12258  0.443331  0.443256  0.442907 -2.602156 -0.098883  0.424035  0.497490
# 12259  0.453262  0.453150  0.452809 -2.587879 -0.172786  0.433631  0.504298
# 12260  0.454007  0.453836  0.453480 -2.588082 -0.172308  0.435431  0.497767
# 12261  0.454639  0.454452  0.454079 -2.588305 -0.171889  0.439607  0.487116
# 12262  0.455629  0.455407  0.455035 -2.588522 -0.171172  0.441391  0.477618
#
#         gyr_z_n  cluster
# 3082   0.411197        1
# 3083   0.408000        1
# 3084   0.451051        1
# 3085   0.448582        1
# 3086   0.445861        1
# ...         ...      ...
# 12258  0.450021        1
# 12259  0.463515        1
# 12260  0.465869        1
# 12261  0.470302        1
# 12262  0.474615        1
#
# [136 rows x 9 columns]

# %%
cluster_df.to_csv("Clustered_Movement_Data.csv")

# %% [markdown]
# # Evaluate the model

# %%
#possible_k_values = range(2,12)
possible_k_values = [3, 5, 7, 9, 11, 15, 16]

# %%
sum_of_squared_distances = []

for k in possible_k_values:
    k_means = TimeSeriesKMeans(n_clusters=k)
    k_means = k_means.fit(X_train)

    sum_of_squared_distances.append(k_means.inertia_)
    
sum_of_squared_distances[:20]
# Out:
# [0.042861690613435505,
#  0.024679104175536582,
#  0.01240471973259803,
#  0.006599570431322658,
#  0.004633129427879135,
#  0.0027499438601787177,
#  0.0020027694811601327]

# %%
fig, ax = plt.subplots(figsize=(4, 4))

plt.plot(possible_k_values, sum_of_squared_distances, 'rx-')
plt.xlabel('k')
plt.ylabel('Sum of squared distances')

plt.title('Elbow plot for optimal number of clusters')
plt.show()

# %%
scores_df = pd.DataFrame({'k_value' : possible_k_values,
                          'score' : sum_of_squared_distances})

scores_df.head(10)
# Out:
#    k_value     score
# 0        3  0.042862
# 1        5  0.024679
# 2        7  0.012405
# 3        9  0.006600
# 4       11  0.004633
# 5       15  0.002750
# 6       16  0.002003

# %%
def silhouette_score_kmeans(k, data):
    kmean = TimeSeriesKMeans(n_clusters = k).fit(data)
    
    silhou_score = silhouette_score(data, kmean.labels_)

    return silhou_score

# %%
silhouette_score_per_k = []

for k in possible_k_values:
    silhou_score = silhouette_score_kmeans(k, cluster_df_sk)
    
    silhouette_score_per_k.append(silhou_score)
    
silhouette_score_per_k[:20]
# Out:
# [0.6908640107199554,
#  0.5782943487148058,
#  0.5131737829915402,
#  0.542908223001794,
#  0.5432078762750738,
#  0.5408509450062253,
#  0.5387782069726819]

# %%
scores_df = pd.DataFrame({'k_value' : possible_k_values,
                          'score' : silhouette_score_per_k})

scores_df.head(20)
# Out:
#    k_value     score
# 0        3  0.690864
# 1        5  0.578294
# 2        7  0.513174
# 3        9  0.542908
# 4       11  0.543208
# 5       15  0.540851
# 6       16  0.538778

# %%
fig, ax = plt.subplots(figsize=(4, 4))

plt.plot(possible_k_values, silhouette_score_per_k, 'gx-')
plt.xlabel('k')
plt.ylabel('Silhouette score')

plt.title('Silhouette score per number of clusters')
plt.show()
